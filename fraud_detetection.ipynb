# %% [markdown]
# ### Task 5 : Credit Card Fruad Detection

# %% [markdown]
# Importing required modules

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, f1_score

from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# Loading data

# %%
dataset = pd.read_csv("creditcard.csv")
data = dataset.copy()

# %% [markdown]
# Data inspection

# %%
data.head(4)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# Data summary statistics

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# Pre-processing EDA

# %%
plt.figure(figsize=(16,5))
data.drop(columns=["Time","Amount"]).boxplot()
plt.show()

# %%
#Note : outliers are required for this specific problem statement

# %% [markdown]
# Data pre-processing

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# Data Splitting

# %%
X = data.drop(columns=["Class"])
y = data["Class"]
X.shape, y.shape
# Out:
# ((284807, 30), (284807,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,stratify=y)

# %% [markdown]
# Balancing data

# %%
plt.bar(y.value_counts(normalize=True).index,
        y.value_counts(normalize=True).values,
       color=["#4A4A4A","#838383","#ADACAC"])
plt.text(2.3,0.5,"Here the target variables are not balanced i.e \n99% : Non-fraud(0) , 1% : Fraud(1)",fontsize=15)
plt.text(2.3,0.35,"Thus we need to balance the data.",fontsize=12)
plt.show()

# %%
smote_tomek = SMOTE(sampling_strategy='auto', random_state=42, n_jobs=-1)
X_resampled, y_resampled = smote_tomek.fit_resample(X_train, y_train)

# %% [markdown]
# Model Selection

# %% [markdown]
# - Model training

# %%
plt.bar(y_resampled.value_counts(normalize=True).index,
        y_resampled.value_counts(normalize=True).values,
       color=["#838383","#838383","#838383"])
plt.text(2.3,0.23,"Here the target variables have been balanced equally using SMOTE",fontsize=15)
plt.show()

# %%
#Random forest model
rf_model = RandomForestClassifier().fit(X_resampled, y_resampled)

# %%
#Linear regresssion model
linear_model = LogisticRegression().fit(X_resampled, y_resampled)

# %%
#Gradient boosting model
gb_model = GradientBoostingClassifier().fit(X_resampled, y_resampled)

# %% [markdown]
# - Making predictions

# %%
#Linear regresssion predictions
linear_preds = linear_model.predict(X_test)

#Random forest predictions
rf_preds = rf_model.predict(X_test)

#Gradient boosting predictions
gb_preds = gb_model.predict(X_test)

# %% [markdown]
# Model Evaluation

# %%
def evaluate(model_name, y_preds, y_test=y_test):
    # Error Metrics
    acc = accuracy_score(y_test, y_preds)
    recall = recall_score(y_test, y_preds,average="weighted" )
    precision = precision_score(y_test, y_preds,average="weighted" )
    f1 = f1_score(y_test, y_preds,average="weighted" )
    print(f"Model : {model_name}")
    print(f'accuracy_score: {acc:.2f}')
    print(f'recall_score: {recall:.2f}')
    print(f'precision_score: {precision:.2f}')
    print(f'f1_score: {f1:.2f}\n')
    print(f"Confusion matrix: \n{confusion_matrix(y_test, y_preds)}")
    print("\nClassification report:")
    print(classification_report(y_test, y_preds))

# %%
evaluate("Linear regression",linear_preds)
# Out:
# Model : Linear regression
# accuracy_score: 0.98
# recall_score: 0.98
# precision_score: 1.00
# f1_score: 0.99
#
# Confusion matrix:
# [[69821  1258]
#  [   12   111]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     71079
#            1       0.08      0.90      0.15       123
#
#     accuracy                           0.98     71202
#    macro avg       0.54      0.94      0.57     71202
# weighted avg       1.00      0.98      0.99     71202

# %%
evaluate("random forest",rf_preds)
# Out:
# Model : random forest
# accuracy_score: 1.00
# recall_score: 1.00
# precision_score: 1.00
# f1_score: 1.00
#
# Confusion matrix:
# [[71066    13]
#  [   23   100]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.88      0.81      0.85       123
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.91      0.92     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
evaluate("gradient boosting", gb_preds)
# Out:
# Model : gradient boosting
# accuracy_score: 0.99
# recall_score: 0.99
# precision_score: 1.00
# f1_score: 1.00
#
# Confusion matrix:
# [[70683   396]
#  [   13   110]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     71079
#            1       0.22      0.89      0.35       123
#
#     accuracy                           0.99     71202
#    macro avg       0.61      0.94      0.67     71202
# weighted avg       1.00      0.99      1.00     71202

# %% [markdown]
# Conclusion

# %% [markdown]
# - Random forest is giving the best results
